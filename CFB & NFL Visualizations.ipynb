# %%
from datetime import date as dt
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import os.path
import io

# %%
raiders_data = pd.read_csv("raiders.csv")
raiders_data = pd.DataFrame(raiders_data)
raiders_data.head(5)
# Out:
#   Unnamed: 0 Unnamed: 1            Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0       Year         Lg                    Tm          W          L
# 1        NaN        NaN                   NaN        NaN        NaN
# 2       1994        NFL   Los Angeles Raiders          9          7
# 3       1993        NFL  Los Angeles Raiders*         10          6
# 4       1992        NFL   Los Angeles Raiders          7          9
#
#   Unnamed: 5   Unnamed: 6 Unnamed: 7 Points Points.1  ... Def Rank.1  \
# 0          T  Div. Finish   Playoffs     PF       PA  ...        Yds
# 1        NaN          NaN        NaN    NaN      NaN  ...        NaN
# 2          0     3rd of 5        NaN    303      327  ...         10
# 3          0     2nd of 5   Lost Div    306      326  ...          9
# 4          0     4th of 5        NaN    249      281  ...          9
#
#   Overall Rank Overall Rank.1 Overall Rank.2 Overall Rank.3  \
# 0          T/G           Pts±           Yds±         out of
# 1          NaN            NaN            NaN            NaN
# 2           22             15             14             28
# 3           18             18             10             28
# 4           28             15             14             28
#
#   Simple Rating System Simple Rating System.1 Simple Rating System.2  \
# 0                  MoV                    SoS                    SRS
# 1                  NaN                    NaN                    NaN
# 2                 -1.5                   -0.1                   -1.6
# 3                 -1.3                    0.6                   -0.7
# 4                 -2.0                    0.4                   -1.6
#
#   Simple Rating System.3 Simple Rating System.4
# 0                   OSRS                   DSRS
# 1                    NaN                    NaN
# 2                   -1.9                    0.3
# 3                    1.1                   -1.7
# 4                   -3.2                    1.5
#
# [5 rows x 29 columns]

# %%
# Getting first (0th) row of the "Unnamed: 0" col
raiders_data.loc[0, 'Unnamed: 0']
# Out:
# 'Year'

# %% [markdown]
# # Fixing Column Names

# %%
# fixnig columns names
raiders_data.rename(columns = {'Unnamed: 0':raiders_data.loc[0,'Unnamed: 0']})
# Out:
#     Year Unnamed: 1            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   Year         Lg                    Tm          W          L          T
# 1    NaN        NaN                   NaN        NaN        NaN        NaN
# 2   1994        NFL   Los Angeles Raiders          9          7          0
# 3   1993        NFL  Los Angeles Raiders*         10          6          0
# 4   1992        NFL   Los Angeles Raiders          7          9          0
# 5   1991        NFL  Los Angeles Raiders*          9          7          0
# 6   1990        NFL  Los Angeles Raiders*         12          4          0
# 7   1989        NFL   Los Angeles Raiders          8          8          0
# 8   1988        NFL   Los Angeles Raiders          7          9          0
# 9   1987        NFL   Los Angeles Raiders          5         10          0
# 10  1986        NFL   Los Angeles Raiders          8          8          0
# 11  1985        NFL  Los Angeles Raiders*         12          4          0
# 12  1984        NFL  Los Angeles Raiders*         11          5          0
# 13  1983        NFL  Los Angeles Raiders*         12          4          0
# 14  1982        NFL  Los Angeles Raiders*          8          1          0
#
#      Unnamed: 6 Unnamed: 7 Points Points.1  ... Def Rank.1 Overall Rank  \
# 0   Div. Finish   Playoffs     PF       PA  ...        Yds          T/G
# 1           NaN        NaN    NaN      NaN  ...        NaN          NaN
# 2      3rd of 5        NaN    303      327  ...         10           22
# 3      2nd of 5   Lost Div    306      326  ...          9           18
# 4      4th of 5        NaN    249      281  ...          9           28
# 5      3rd of 5    Lost WC    298      297  ...         21           11
# 6      1st of 5  Lost Conf    337      268  ...          4           14
# 7      3rd of 5        NaN    315      297  ...         10           16
# 8      3rd of 5        NaN    325      369  ...         19           12
# 9      4th of 5        NaN    301      289  ...          5           16
# 10     4th of 5        NaN    323      346  ...          3           24
# 11     1st of 5   Lost Div    354      308  ...          4           24
# 12     3rd of 5    Lost WC    368      278  ...          3           27
# 13     1st of 5     Won SB    442      338  ...          4           23
# 14     1st of 5   Lost Div    260      200  ...         22            5
#
#    Overall Rank.1 Overall Rank.2 Overall Rank.3 Simple Rating System  \
# 0            Pts±           Yds±         out of                  MoV
# 1             NaN            NaN            NaN                  NaN
# 2              15             14             28                 -1.5
# 3              18             10             28                 -1.3
# 4              15             14             28                 -2.0
# 5              15             24             28                  0.1
# 6               9             13             28                  4.3
# 7              13             16             28                  1.1
# 8              18             21             28                 -2.8
# 9              11              3             28                  0.8
# 10             18              6             28                 -1.4
# 11              9              5             28                  2.9
# 12              6              5             28                  5.6
# 13              5              2             28                  6.5
# 14              6             16             28                  6.7
#
#    Simple Rating System.1 Simple Rating System.2 Simple Rating System.3  \
# 0                     SoS                    SRS                   OSRS
# 1                     NaN                    NaN                    NaN
# 2                    -0.1                   -1.6                   -1.9
# 3                     0.6                   -0.7                    1.1
# 4                     0.4                   -1.6                   -3.2
# 5                     1.3                    1.4                    0.3
# 6                     2.2                    6.6                    2.2
# 7                     0.7                    1.8                    0.0
# 8                    -0.8                   -3.6                   -0.3
# 9                    -0.8                    0.0                   -1.6
# 10                    1.6                    0.2                    0.0
# 11                    1.5                    4.3                    0.7
# 12                    1.2                    6.9                    2.1
# 13                    0.3                    6.8                    5.1
# 14                   -1.5                    5.2                    6.1
#
#    Simple Rating System.4
# 0                    DSRS
# 1                     NaN
# 2                     0.3
# 3                    -1.7
# 4                     1.5
# 5                     1.1
# 6                     4.4
# 7                     1.9
# 8                    -3.3
# 9                     1.7
# 10                    0.2
# 11                    3.7
# 12                    4.8
# 13                    1.7
# 14                   -0.9
#
# [15 rows x 29 columns]

# %%
raiders_data.head(3)
# Out:
#   Unnamed: 0 Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       Year         Lg                   Tm          W          L          T
# 1        NaN        NaN                  NaN        NaN        NaN        NaN
# 2       1994        NFL  Los Angeles Raiders          9          7          0
#
#     Unnamed: 6 Unnamed: 7 Points Points.1  ... Def Rank.1 Overall Rank  \
# 0  Div. Finish   Playoffs     PF       PA  ...        Yds          T/G
# 1          NaN        NaN    NaN      NaN  ...        NaN          NaN
# 2     3rd of 5        NaN    303      327  ...         10           22
#
#   Overall Rank.1 Overall Rank.2 Overall Rank.3 Simple Rating System  \
# 0           Pts±           Yds±         out of                  MoV
# 1            NaN            NaN            NaN                  NaN
# 2             15             14             28                 -1.5
#
#   Simple Rating System.1 Simple Rating System.2 Simple Rating System.3  \
# 0                    SoS                    SRS                   OSRS
# 1                    NaN                    NaN                    NaN
# 2                   -0.1                   -1.6                   -1.9
#
#   Simple Rating System.4
# 0                   DSRS
# 1                    NaN
# 2                    0.3
#
# [3 rows x 29 columns]

# %%
raiders_data.loc[0,raiders_data.columns[28]]
# Out:
# 'DSRS'

# %%
# range function specifies the amount of time to run the loop for col number
for i in range(raiders_data.shape[1]):
    col = raiders_data.columns[i]
    raiders_data.rename(columns = {col: raiders_data.loc[0,col]}, inplace = True)
    
raiders_data.head(5)
# Out:
#    Year   Lg                    Tm    W    L    T  Div. Finish  Playoffs   PF  \
# 0  Year   Lg                    Tm    W    L    T  Div. Finish  Playoffs   PF
# 1   NaN  NaN                   NaN  NaN  NaN  NaN          NaN       NaN  NaN
# 2  1994  NFL   Los Angeles Raiders    9    7    0     3rd of 5       NaN  303
# 3  1993  NFL  Los Angeles Raiders*   10    6    0     2nd of 5  Lost Div  306
# 4  1992  NFL   Los Angeles Raiders    7    9    0     4th of 5       NaN  249
#
#     PA  ...  Yds  T/G  Pts±  Yds±  out of   MoV   SoS   SRS  OSRS  DSRS
# 0   PA  ...  Yds  T/G  Pts±  Yds±  out of   MoV   SoS   SRS  OSRS  DSRS
# 1  NaN  ...  NaN  NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN
# 2  327  ...   10   22    15    14      28  -1.5  -0.1  -1.6  -1.9   0.3
# 3  326  ...    9   18    18    10      28  -1.3   0.6  -0.7   1.1  -1.7
# 4  281  ...    9   28    15    14      28  -2.0   0.4  -1.6  -3.2   1.5
#
# [5 rows x 29 columns]
