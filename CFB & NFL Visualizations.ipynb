# %%
from datetime import date as dt
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import os.path
import io

# %%
raiders_data = pd.read_csv("raiders.csv")
raiders_data = pd.DataFrame(raiders_data)
raiders_data.head(5)
# Out:
#   Unnamed: 0 Unnamed: 1            Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0       Year         Lg                    Tm          W          L
# 1        NaN        NaN                   NaN        NaN        NaN
# 2       1994        NFL   Los Angeles Raiders          9          7
# 3       1993        NFL  Los Angeles Raiders*         10          6
# 4       1992        NFL   Los Angeles Raiders          7          9
#
#   Unnamed: 5   Unnamed: 6 Unnamed: 7 Points Points.1  ... Def Rank.1  \
# 0          T  Div. Finish   Playoffs     PF       PA  ...        Yds
# 1        NaN          NaN        NaN    NaN      NaN  ...        NaN
# 2          0     3rd of 5        NaN    303      327  ...         10
# 3          0     2nd of 5   Lost Div    306      326  ...          9
# 4          0     4th of 5        NaN    249      281  ...          9
#
#   Overall Rank Overall Rank.1 Overall Rank.2 Overall Rank.3  \
# 0          T/G           Pts±           Yds±         out of
# 1          NaN            NaN            NaN            NaN
# 2           22             15             14             28
# 3           18             18             10             28
# 4           28             15             14             28
#
#   Simple Rating System Simple Rating System.1 Simple Rating System.2  \
# 0                  MoV                    SoS                    SRS
# 1                  NaN                    NaN                    NaN
# 2                 -1.5                   -0.1                   -1.6
# 3                 -1.3                    0.6                   -0.7
# 4                 -2.0                    0.4                   -1.6
#
#   Simple Rating System.3 Simple Rating System.4
# 0                   OSRS                   DSRS
# 1                    NaN                    NaN
# 2                   -1.9                    0.3
# 3                    1.1                   -1.7
# 4                   -3.2                    1.5
#
# [5 rows x 29 columns]

# %%
# Getting first (0th) row of the "Unnamed: 0" col
raiders_data.loc[0, 'Unnamed: 0']
# Out:
# 'Year'

# %% [markdown]
# # Fixing Column Names

# %%
raiders_data.loc[0,raiders_data.columns[28]]
# Out:
# 'DSRS'

# %%
# range function specifies the amount of time to run the loop for col number
for i in range(raiders_data.shape[1]):
    col = raiders_data.columns[i]
    raiders_data.rename(columns = {col: raiders_data.loc[0,col]}, inplace = True)

# getting rid of the first 2 rows
raiders_data.drop([raiders_data.index[0], raiders_data.index[1]], inplace = True)

raiders_data.head(5)
# Out:
#    Year   Lg                    Tm   W  L  T Div. Finish   Playoffs   PF   PA  \
# 2  1994  NFL   Los Angeles Raiders   9  7  0    3rd of 5        NaN  303  327
# 3  1993  NFL  Los Angeles Raiders*  10  6  0    2nd of 5   Lost Div  306  326
# 4  1992  NFL   Los Angeles Raiders   7  9  0    4th of 5        NaN  249  281
# 5  1991  NFL  Los Angeles Raiders*   9  7  0    3rd of 5    Lost WC  298  297
# 6  1990  NFL  Los Angeles Raiders*  12  4  0    1st of 5  Lost Conf  337  268
#
#    ... Yds T/G Pts± Yds± out of   MoV   SoS   SRS  OSRS  DSRS
# 2  ...  10  22   15   14     28  -1.5  -0.1  -1.6  -1.9   0.3
# 3  ...   9  18   18   10     28  -1.3   0.6  -0.7   1.1  -1.7
# 4  ...   9  28   15   14     28  -2.0   0.4  -1.6  -3.2   1.5
# 5  ...  21  11   15   24     28   0.1   1.3   1.4   0.3   1.1
# 6  ...   4  14    9   13     28   4.3   2.2   6.6   2.2   4.4
#
# [5 rows x 29 columns]

# %% [markdown]
# # Fixing other NFL datasets

# %%
chargers_data = pd.read_csv('chargers.csv')
rams_data = pd.read_csv('rams.csv')

# %% [markdown]
# # Chargers Data

# %%
# range function specifies the amount of time to run the loop for col number
for i in range(chargers_data.shape[1]):
    col = chargers_data.columns[i]
    chargers_data.rename(columns = {col: chargers_data.loc[0,col]}, inplace = True)

# getting rid of the first 2 rows
chargers_data.drop([chargers_data.index[0], chargers_data.index[1]], inplace = True)

chargers_data.head(5)
# Out:
#    Year   Lg                     Tm   W   L  T Div. Finish  Playoffs   PF  \
# 2  2022  NFL   Los Angeles Chargers   2   2  0    2nd of 4       NaN   92
# 3  2021  NFL   Los Angeles Chargers   9   8  0    3rd of 4       NaN  474
# 4  2020  NFL   Los Angeles Chargers   7   9  0    3rd of 4       NaN  384
# 5  2019  NFL   Los Angeles Chargers   5  11  0    4th of 4       NaN  337
# 6  2018  NFL  Los Angeles Chargers*  12   4  0    2nd of 4  Lost Div  428
#
#     PA  ... Yds T/G Pts± Yds± out of   MoV   SoS   SRS  OSRS  DSRS
# 2  108  ...  20   8   22   11     32  -4.0  -0.7  -4.7  -5.6   0.9
# 3  459  ...  23  19   16    9     32   0.9   0.2   1.1   5.3  -4.2
# 4  426  ...  10  13   20    9     32  -2.6  -0.3  -2.9  -1.0  -2.0
# 5  345  ...   6  31   16    5     32  -0.5  -0.8  -1.3  -1.6   0.3
# 6  329  ...   9  15    7    6     32   6.2  -0.2   6.0   3.0   2.9
#
# [5 rows x 29 columns]

# %% [markdown]
# # Rams Data

# %%
# range function specifies the amount of time to run the loop for col number
for i in range(rams_data.shape[1]):
    col = rams_data.columns[i]
    rams_data.rename(columns = {col: rams_data.loc[0,col]}, inplace = True)

# getting rid of the first 2 rows
rams_data.drop([rams_data.index[0], rams_data.index[1]], inplace = True)

rams_data.head(5)
# Out:
#    Year   Lg                 Tm   W  L  T Div. Finish  Playoffs   PF   PA  \
# 2  2021  NFL  Los Angeles Rams*  12  5  0    1st of 4    Won SB  460  372
# 3  2020  NFL  Los Angeles Rams*  10  6  0    2nd of 4  Lost Div  372  296
# 4  2019  NFL   Los Angeles Rams   9  7  0    3rd of 4       NaN  394  364
# 5  2018  NFL  Los Angeles Rams*  13  3  0    1st of 4   Lost SB  527  384
# 6  2017  NFL  Los Angeles Rams*  11  5  0    1st of 4   Lost WC  478  329
#
#    ... Yds T/G Pts± Yds± out of  MoV   SoS  SRS  OSRS  DSRS
# 2  ...  17  13    6   12     32  5.2   0.1  5.3   4.2   1.1
# 3  ...   1  21   10    1     32  4.8   0.7  5.4  -0.8   6.2
# 4  ...  13  15   12    8     32  1.9   2.0  3.9   2.2   1.7
# 5  ...  19   4    3    3     32  8.9  -0.4  8.5   9.5  -1.1
# 6  ...  19   9    3   10     32  9.3  -0.2  9.2   8.2   1.0
#
# [5 rows x 29 columns]
