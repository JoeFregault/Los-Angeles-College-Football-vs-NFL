# %%
from datetime import date as dt
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os.path
import io

# %%
ucla_data = pd.read_csv("ucla.csv")
ucla_data.head(5)
# Out:
#    Rk  Year    Conf  Overall W  Overall L  Overall T  Overall Pct  \
# 0   1  2022  Pac-12          5          0        NaN        1.000
# 1   2  2021  Pac-12          8          4        0.0        0.667
# 2   3  2020  Pac-12          3          4        0.0        0.429
# 3   4  2019  Pac-12          4          8        0.0        0.333
# 4   5  2018  Pac-12          3          9        0.0        0.250
#
#    Conference W  Conference L  Conference T  Conference Pct    SRS   SOS  \
# 0             2             0             0           1.000  14.38 -3.02
# 1             6             3             0           0.667   7.25 -0.25
# 2             3             4             0           0.429  -0.11 -2.97
# 3             4             5             0           0.444  -0.55  4.95
# 4             3             6             0           0.333  -2.19  6.73
#
#    AP Pre  AP High  AP Post         Coach(es) Bowl Notes
# 0     NaN     18.0      NaN  Chip Kelly (5-0)  NaN   NaN
# 1     NaN     13.0      NaN  Chip Kelly (8-4)  NaN   NaN
# 2     NaN      NaN      NaN  Chip Kelly (3-4)  NaN   NaN
# 3     NaN      NaN      NaN  Chip Kelly (4-8)  NaN   NaN
# 4     NaN      NaN      NaN  Chip Kelly (3-9)  NaN   NaN

# %%
# Fixing Column Names
#ucla_data['Overall'] =

# %%
# Setting a large size for future plots
sns.set(rc = {'figure.figsize':(20,12)})

# %%
wins = ucla_data['Overall W'].values
ucla_graph = sns.lineplot(ucla_data['Year'].values, wins,  color= 'blue').set_title("UCLA Football Wins Over Time",
                                                                                   fontsize=30)
